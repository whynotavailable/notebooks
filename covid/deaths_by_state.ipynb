# %% [markdown]
# # Some covid stats

# %%
import pandas
import numpy as np

# %%
df = pandas.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-02-2020.csv')
df['Confirmed'] = df['Confirmed'].astype(int)
df['Deaths'] = df['Deaths'].astype(int)
df['Recovered'] = df['Recovered'].astype(int)
df = df[df['Country_Region'] == 'US']

# %%
def render_grouping(col):
    df2 = df.groupby(col).sum().sort_values(by=['Confirmed'], ascending=False)
    df2["Row #"] = np.arange(len(df2)) + 1
    return df2.filter(items=['Row #', 'Confirmed', 'Deaths', 'Recovered'])

# %% [markdown]
# Here we have grouped by US state

# %%
render_grouping('Province_State')
# Out:
#                           Row #  Confirmed  Deaths  Recovered
# Province_State
# New York                      1      92506    2373          0
# New Jersey                    2      25590     537          0
# Michigan                      3      10791     417          0
# California                    4      10773     238          0
# Louisiana                     5       9159     310          0
# Florida                       6       9008     164          0
# Massachusetts                 7       8966     154          0
# Illinois                      8       7695     163          0
# Pennsylvania                  9       7268      90          0
# Washington                   10       6389     271          0
# Georgia                      11       5348     163          0
# Texas                        12       5069      77          0
# Connecticut                  13       3824     112          0
# Colorado                     14       3342      80          0
# ...

# %% [markdown]
# Grouping by us cities

# %%
render_grouping('Combined_Key').head(50)
# Out:
#                                 Row #  Confirmed  Deaths  Recovered
# Combined_Key
# New York City, New York, US         1      51809    1397          0
# Westchester, New York, US           2      11567      64          0
# Nassau, New York, US                3      10587      76          0
# Suffolk, New York, US               4       8746      69          0
# Cook, Illinois, US                  5       5575     107          0
# Wayne,Michigan,US                   6       5069     194          0
# Unassigned, New Jersey, US          7       4866       4          0
# Bergen, New Jersey, US              8       4099     120          0
# Los Angeles, California, US         9       4045      78          0
# Rockland, New York, US             10       3751      18          0
# Orleans, Louisiana, US             11       3148     125          0
# Miami-Dade, Florida, US            12       2886      20          0
# King, Washington, US               13       2656     175          0
# ...
